# %% [markdown]
# ## Importing packages

# %%
import pandas as pd
import numpy as np
import missingno as msno
import seaborn as sns
from sklearn.impute import KNNImputer
from sklearn.calibration import LabelEncoder
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn import preprocessing
from dateutil.parser import parse
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data  loading

# %%
data = pd.DataFrame(pd.read_csv('Train.csv'))

# %%
data
# Out:
#            ID       date       campaign_type region customer_age_range  \
# 0      Kq6531  2/19/2019  Online Advertising   East                56+
# 1      Zh5785   4/8/2019  Online Advertising  North                56+
# 2      Si1260  6/28/2018                  TV    NaN              26-35
# 3      Hl5016  6/10/2019                 NaN   West                NaN
# 4      Dj9025  7/14/2018               Email   East              36-45
# ...       ...        ...                 ...    ...                ...
# 11993  Kk3455  7/26/2018                  TV   East              46-55
# 11994  Yd3578  9/27/2021  Direct Advertising   East                NaN
# 11995  Ao1925   6/1/2019  Direct Advertising    NaN                NaN
# 11996  Vf8403  7/21/2020                 NaN   East              46-55
# 11997  Ap3780  8/14/2018  Online Advertising   West              26-35
#
#        gender      sales  units_sold  clients_engaged  click_rate  \
# 0        Male  100735.32        64.0           2364.0        0.13
# 1      Female   15722.29        77.0            684.0        0.24
# 2         NaN   35385.73         1.0           2299.0        0.51
# 3         NaN  116045.50        44.0           2332.0        0.97
# 4         NaN   65039.93        20.0           2564.0        0.36
# ...       ...        ...         ...              ...         ...
# 11993     NaN   79508.92        80.0           2203.0        1.29
# 11994  Others  102306.08        52.0           2386.0        0.41
# 11995    Male  117407.35        65.0           2511.0        0.64
# 11996    Male    4728.01        59.0           2736.0        0.08
# 11997  Female   36322.69        76.0           1052.0        0.53
#
#        conversion_rate  satisfaction_client (%)
# 0                 0.13                     92.2
# 1                 0.13                     72.6
# 2                 0.08                     55.0
# 3                 0.09                     68.0
# 4                 0.26                     50.8
# ...                ...                      ...
# 11993             0.27                     55.4
# 11994             0.05                     70.4
# 11995             0.25                     70.0
# 11996             0.08                     30.0
# 11997             0.25                     92.4
#
# [11998 rows x 12 columns]

# %% [markdown]
# ## Overview of the dataset

# %%
data.shape
# Out:
# (11998, 12)

# %%
data.columns
# Out:
# Index(['ID', 'date', 'campaign_type', 'region', 'customer_age_range', 'gender',
#        'sales', 'units_sold', 'clients_engaged', 'click_rate',
#        'conversion_rate', 'satisfaction_client (%)'],
#       dtype='object')

# %%
# data types of all dataframe's columns
data.dtypes
# Out:
# ID                          object
# date                        object
# campaign_type               object
# region                      object
# customer_age_range          object
# gender                      object
# sales                      float64
# units_sold                 float64
# clients_engaged            float64
# click_rate                 float64
# conversion_rate            float64
# satisfaction_client (%)    float64
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11998 entries, 0 to 11997
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       11998 non-null  object
#  1   date                     11989 non-null  object
#  2   campaign_type            10055 non-null  object
#  3   region                   9634 non-null   object
#  4   customer_age_range       10023 non-null  object
#  5   gender                   9042 non-null   object
#  6   sales                    11984 non-null  float64
#  7   units_sold               11983 non-null  float64
#  8   clients_engaged          11984 non-null  float64
#  9   click_rate               11982 non-null  float64
#  10  conversion_rate          11982 non-null  float64
#  11  satisfaction_client (%)  11998 non-null  float64
# dtypes: float64(6), object(6)
# memory usage: 1.1+ MB

# %%
data.describe()
# Out:
#               sales    units_sold  clients_engaged    click_rate  \
# count   11984.00000  11983.000000     11984.000000  11982.000000
# mean    75617.91220     50.640324      1498.984479      0.778186
# std     42964.09485     28.513605       863.584033      0.422679
# min       518.26000      1.000000        10.000000      0.050000
# 25%     38744.54250     26.000000       756.000000      0.410000
# 50%     75876.94000     51.000000      1499.000000      0.780000
# 75%    112795.31750     75.000000      2246.000000      1.140000
# max    149985.57000    100.000000      3000.000000      1.500000
#
#        conversion_rate  satisfaction_client (%)
# count     11982.000000             11998.000000
# mean          0.155815                60.166694
# std           0.083265                23.247744
# min           0.010000                20.000000
# 25%           0.080000                40.000000
# 50%           0.160000                60.200000
# 75%           0.230000                80.600000
# max           0.300000               100.000000

# %%
# duplicates
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Cleaning And Transformation of the Data

# %% [markdown]
# #### date formatting

# %%
#convert date columns to actual date columns
for col in data.columns:
    if data[col].dtype == 'object':
        try:
            data[col] = pd.to_datetime(data[col])
        except ValueError:
            pass
# the date format now is "YYYY-MM-DD  HH:mm:ss", get_date_format method is meant to remove the last part of the date
def get_date_format(date_string):
    try:
        parsed_date = parse(date_string, fuzzy=True)
        return parsed_date.strftime('%Y-%m-%d')
    except ValueError:
        return None
data['date'] = data['date'].apply(lambda x: get_date_format(str(x)))
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_1408\2361594143.py:5: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data[col] = pd.to_datetime(data[col])
# C:\Users\Dell\AppData\Local\Temp\ipykernel_1408\2361594143.py:5: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data[col] = pd.to_datetime(data[col])
# C:\Users\Dell\AppData\Local\Temp\ipykernel_1408\2361594143.py:5: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data[col] = pd.to_datetime(data[col])
# C:\Users\Dell\AppData\Local\Temp\ipykernel_1408\2361594143.py:5: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data[col] = pd.to_datetime(data[col])
# C:\Users\Dell\AppData\Local\Temp\ipykernel_1408\2361594143.py:5: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data[col] = pd.to_datetime(data[col])

# %%
data.date.unique()
# Out:
# array(['2019-02-19', '2019-04-08', '2018-06-28', ..., '2018-10-12',
#        '2019-11-18', '2019-05-16'], dtype=object)

# %%
# Identifying missing values for each column in the dataframe
data.isnull().sum()
# Out:
# ID                            0
# date                          9
# campaign_type              1943
# region                     2364
# customer_age_range         1975
# gender                     2956
# sales                        14
# units_sold                   15
# clients_engaged              14
# click_rate                   16
# conversion_rate              16
# satisfaction_client (%)       0
# dtype: int64

# %%
# visualize the missing values using missingo matrix
msno.bar(data, figsize=(14,6), fontsize=12, color="seagreen",  sort="descending")
# Out:
# <Axes: >

# %%
data
# Out:
#            ID        date       campaign_type region customer_age_range  \
# 0      Kq6531  2019-02-19  Online Advertising   East                56+
# 1      Zh5785  2019-04-08  Online Advertising  North                56+
# 2      Si1260  2018-06-28                  TV    NaN              26-35
# 3      Hl5016  2019-06-10                 NaN   West                NaN
# 4      Dj9025  2018-07-14               Email   East              36-45
# ...       ...         ...                 ...    ...                ...
# 11993  Kk3455  2018-07-26                  TV   East              46-55
# 11994  Yd3578  2021-09-27  Direct Advertising   East                NaN
# 11995  Ao1925  2019-06-01  Direct Advertising    NaN                NaN
# 11996  Vf8403  2020-07-21                 NaN   East              46-55
# 11997  Ap3780  2018-08-14  Online Advertising   West              26-35
#
#        gender      sales  units_sold  clients_engaged  click_rate  \
# 0        Male  100735.32        64.0           2364.0        0.13
# 1      Female   15722.29        77.0            684.0        0.24
# 2         NaN   35385.73         1.0           2299.0        0.51
# 3         NaN  116045.50        44.0           2332.0        0.97
# 4         NaN   65039.93        20.0           2564.0        0.36
# ...       ...        ...         ...              ...         ...
# 11993     NaN   79508.92        80.0           2203.0        1.29
# 11994  Others  102306.08        52.0           2386.0        0.41
# 11995    Male  117407.35        65.0           2511.0        0.64
# 11996    Male    4728.01        59.0           2736.0        0.08
# 11997  Female   36322.69        76.0           1052.0        0.53
#
#        conversion_rate  satisfaction_client (%)
# 0                 0.13                     92.2
# 1                 0.13                     72.6
# 2                 0.08                     55.0
# 3                 0.09                     68.0
# 4                 0.26                     50.8
# ...                ...                      ...
# 11993             0.27                     55.4
# 11994             0.05                     70.4
# 11995             0.25                     70.0
# 11996             0.08                     30.0
# 11997             0.25                     92.4
#
# [11998 rows x 12 columns]

# %% [markdown]
# #### 1. Implementing MICE algorithm for filling the missing values in categorical columns

# %%
# Implementation of the MICE algorithm for categorical variables
def MiceAlgorithm(col):
    # change the values categ to numbers 
    le = preprocessing.LabelEncoder()
    impute_col = col
    impute_col_encoded = col

    le.fit(data.loc[:,impute_col])
    LabelEncoder()

    # label mapping
    dict(zip(le.classes_,le.transform(le.classes_)))
    d = dict(zip(le.classes_,le.transform(le.classes_)))[np.nan]
    print(d)
    data[impute_col_encoded] = le.transform(data[impute_col])

    # Replace the 4 mapped to NaN to NaN in the encoded column
    data[impute_col_encoded] = data[impute_col_encoded].map(lambda x: np.nan if x==d else x)
    # data.head()


    # Start MICE imputation
    imputer  = IterativeImputer(random_state=100)
    train = data.loc[:,['sales','clients_engaged','click_rate','conversion_rate',impute_col_encoded]]
    imputer.fit(train)
    IterativeImputer(random_state=100)
    data_imputed = imputer.transform(train)
    # data_imputed
    # Rounding the data 
    np.round(data_imputed)
    # Replace with the imputed values
    data.loc[:,[impute_col_encoded]] = data_imputed[:,4].round()
    # Inverse transformation to categorical values
    gender_imputed = list(le.inverse_transform(data[impute_col_encoded].round().astype(int)))
    data[impute_col_encoded] = gender_imputed

# %%
MiceAlgorithm('campaign_type')
data.head()
# Out:
# 5
#        ID        date       campaign_type region customer_age_range  gender  \
# 0  Kq6531  2019-02-19  Online Advertising   East                56+    Male
# 1  Zh5785  2019-04-08  Online Advertising  North                56+  Female
# 2  Si1260  2018-06-28                  TV    NaN              26-35     NaN
# 3  Hl5016  2019-06-10  Online Advertising   West                NaN     NaN
# 4  Dj9025  2018-07-14               Email   East              36-45     NaN
#
#        sales  units_sold  clients_engaged  click_rate  conversion_rate  \
# 0  100735.32        64.0           2364.0        0.13             0.13
# 1   15722.29        77.0            684.0        0.24             0.13
# 2   35385.73         1.0           2299.0        0.51             0.08
# 3  116045.50        44.0           2332.0        0.97             0.09
# 4   65039.93        20.0           2564.0        0.36             0.26
#
#    satisfaction_client (%)
# 0                     92.2
# 1                     72.6
# 2                     55.0
# 3                     68.0
# 4                     50.8

# %%
MiceAlgorithm('customer_age_range')
data.head()
# Out:
# 5
#        ID        date       campaign_type region customer_age_range  gender  \
# 0  Kq6531  2019-02-19  Online Advertising   East                56+    Male
# 1  Zh5785  2019-04-08  Online Advertising  North                56+  Female
# 2  Si1260  2018-06-28                  TV    NaN              26-35     NaN
# 3  Hl5016  2019-06-10  Online Advertising   West              36-45     NaN
# 4  Dj9025  2018-07-14               Email   East              36-45     NaN
#
#        sales  units_sold  clients_engaged  click_rate  conversion_rate  \
# 0  100735.32        64.0           2364.0        0.13             0.13
# 1   15722.29        77.0            684.0        0.24             0.13
# 2   35385.73         1.0           2299.0        0.51             0.08
# 3  116045.50        44.0           2332.0        0.97             0.09
# 4   65039.93        20.0           2564.0        0.36             0.26
#
#    satisfaction_client (%)
# 0                     92.2
# 1                     72.6
# 2                     55.0
# 3                     68.0
# 4                     50.8

# %%
MiceAlgorithm('region')
data.head()
# Out:
# 4
#        ID        date       campaign_type region customer_age_range  gender  \
# 0  Kq6531  2019-02-19  Online Advertising   East                56+    Male
# 1  Zh5785  2019-04-08  Online Advertising  North                56+  Female
# 2  Si1260  2018-06-28                  TV  South              26-35     NaN
# 3  Hl5016  2019-06-10  Online Advertising   West              36-45     NaN
# 4  Dj9025  2018-07-14               Email   East              36-45     NaN
#
#        sales  units_sold  clients_engaged  click_rate  conversion_rate  \
# 0  100735.32        64.0           2364.0        0.13             0.13
# 1   15722.29        77.0            684.0        0.24             0.13
# 2   35385.73         1.0           2299.0        0.51             0.08
# 3  116045.50        44.0           2332.0        0.97             0.09
# 4   65039.93        20.0           2564.0        0.36             0.26
#
#    satisfaction_client (%)
# 0                     92.2
# 1                     72.6
# 2                     55.0
# 3                     68.0
# 4                     50.8

# %%
# Apply the algorithm on the categorical data that includes missing values
MiceAlgorithm('gender')
data.head()
# Out:
# 3
#        ID        date       campaign_type region customer_age_range  gender  \
# 0  Kq6531  2019-02-19  Online Advertising   East                56+    Male
# 1  Zh5785  2019-04-08  Online Advertising  North                56+  Female
# 2  Si1260  2018-06-28                  TV  South              26-35    Male
# 3  Hl5016  2019-06-10  Online Advertising   West              36-45    Male
# 4  Dj9025  2018-07-14               Email   East              36-45    Male
#
#        sales  units_sold  clients_engaged  click_rate  conversion_rate  \
# 0  100735.32        64.0           2364.0        0.13             0.13
# 1   15722.29        77.0            684.0        0.24             0.13
# 2   35385.73         1.0           2299.0        0.51             0.08
# 3  116045.50        44.0           2332.0        0.97             0.09
# 4   65039.93        20.0           2564.0        0.36             0.26
#
#    satisfaction_client (%)
# 0                     92.2
# 1                     72.6
# 2                     55.0
# 3                     68.0
# 4                     50.8

# %% [markdown]
# #### 2. Imputation using the mean

# %%
missing_cols = ['sales', 'units_sold', 'clients_engaged', 'click_rate', 'conversion_rate']

# Mean imputation
for col in missing_cols:
    data[col].fillna(data[col].mean(), inplace=True)

data
# Out:
#            ID        date       campaign_type region customer_age_range  \
# 0      Kq6531  2019-02-19  Online Advertising   East                56+
# 1      Zh5785  2019-04-08  Online Advertising  North                56+
# 2      Si1260  2018-06-28                  TV  South              26-35
# 3      Hl5016  2019-06-10  Online Advertising   West              36-45
# 4      Dj9025  2018-07-14               Email   East              36-45
# ...       ...         ...                 ...    ...                ...
# 11993  Kk3455  2018-07-26                  TV   East              46-55
# 11994  Yd3578  2021-09-27  Direct Advertising   East              36-45
# 11995  Ao1925  2019-06-01  Direct Advertising  South              36-45
# 11996  Vf8403  2020-07-21  Online Advertising   East              46-55
# 11997  Ap3780  2018-08-14  Online Advertising   West              26-35
#
#        gender      sales  units_sold  clients_engaged  click_rate  \
# 0        Male  100735.32        64.0           2364.0        0.13
# 1      Female   15722.29        77.0            684.0        0.24
# 2        Male   35385.73         1.0           2299.0        0.51
# 3        Male  116045.50        44.0           2332.0        0.97
# 4        Male   65039.93        20.0           2564.0        0.36
# ...       ...        ...         ...              ...         ...
# 11993    Male   79508.92        80.0           2203.0        1.29
# 11994  Others  102306.08        52.0           2386.0        0.41
# 11995    Male  117407.35        65.0           2511.0        0.64
# 11996    Male    4728.01        59.0           2736.0        0.08
# 11997  Female   36322.69        76.0           1052.0        0.53
#
#        conversion_rate  satisfaction_client (%)
# 0                 0.13                     92.2
# 1                 0.13                     72.6
# 2                 0.08                     55.0
# 3                 0.09                     68.0
# 4                 0.26                     50.8
# ...                ...                      ...
# 11993             0.27                     55.4
# 11994             0.05                     70.4
# 11995             0.25                     70.0
# 11996             0.08                     30.0
# 11997             0.25                     92.4
#
# [11998 rows x 12 columns]

# %% [markdown]
# #### 3. Drop rows with nan value on the column date

# %%
# Deleting the rows where the 'date' value is nan
data.dropna(subset=['date'], inplace=True)
data.head()
# Out:
#        ID        date       campaign_type region customer_age_range  gender  \
# 0  Kq6531  2019-02-19  Online Advertising   East                56+    Male
# 1  Zh5785  2019-04-08  Online Advertising  North                56+  Female
# 2  Si1260  2018-06-28                  TV  South              26-35    Male
# 3  Hl5016  2019-06-10  Online Advertising   West              36-45    Male
# 4  Dj9025  2018-07-14               Email   East              36-45    Male
#
#        sales  units_sold  clients_engaged  click_rate  conversion_rate  \
# 0  100735.32        64.0           2364.0        0.13             0.13
# 1   15722.29        77.0            684.0        0.24             0.13
# 2   35385.73         1.0           2299.0        0.51             0.08
# 3  116045.50        44.0           2332.0        0.97             0.09
# 4   65039.93        20.0           2564.0        0.36             0.26
#
#    satisfaction_client (%)
# 0                     92.2
# 1                     72.6
# 2                     55.0
# 3                     68.0
# 4                     50.8

# %%
data.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# ### Outliers detection

# %%
# Function to detect outliers in a DataFrame using quantile regression method
def detect_outliers(df):
    outlier_indices = []

    for column in df.columns:
        if df[column].dtype in ['int64', 'float64']:
            Q1 = df[column].quantile(0.25)
            Q3 = df[column].quantile(0.75)
            IQR = Q3 - Q1
            lower_bound = Q1 - 1.5 * IQR
            upper_bound = Q3 + 1.5 * IQR
            outliers = df[(df[column] < lower_bound) | (df[column] > upper_bound)].index
            outlier_indices.extend(outliers)

    outlier_indices = list(set(outlier_indices))
    return df.iloc[outlier_indices]

# Detecting outliers
outliers_df = detect_outliers(data)
print("Outliers in the dataset:")
print(outliers_df)
# Out:
# Outliers in the dataset:
# Empty DataFrame
# Columns: [ID, date, campaign_type, region, customer_age_range, gender, sales, units_sold, clients_engaged, click_rate, conversion_rate, satisfaction_client (%)]
# Index: []

# %%
# Visualizing outliers
def plot_outliers(df):
    for column in df.select_dtypes(include=['int64', 'float64']).columns:
        plt.figure(figsize=(8, 6))
        sns.boxplot(data=df[column], orient='h',color='green')
        plt.title(f'Box Plot for {column}')
        plt.xlabel(column)
        plt.show()
plot_outliers(data)

# %% [markdown]
# #### Typos detection using unique values

# %%
for column in data.columns:
    print("Unique date formats in the column:", data[column].unique())
# no typos detected
# Out:
# Unique date formats in the column: ['Kq6531' 'Zh5785' 'Si1260' ... 'Ao1925' 'Vf8403' 'Ap3780']
# Unique date formats in the column: ['2019-02-19' '2019-04-08' '2018-06-28' ... '2018-10-12' '2019-11-18'
#  '2019-05-16']
# Unique date formats in the column: ['Online Advertising' 'TV' 'Email' 'Social Networks' 'Direct Advertising']
# Unique date formats in the column: ['East' 'North' 'South' 'West']
# Unique date formats in the column: ['56+' '26-35' '36-45' '18-25' '46-55']
# Unique date formats in the column: ['Male' 'Female' 'Others']
# Unique date formats in the column: [100735.32  15722.29  35385.73 ... 117407.35   4728.01  36322.69]
# Unique date formats in the column: [ 64.          77.           1.          44.          20.
#    2.          14.          67.          33.          81.
#   51.          85.           3.          78.          82.
#   40.          90.          32.          69.          79.
#   65.          71.          16.          31.          97.
#   63.          49.          72.          25.          91.
#   29.          57.          76.          94.          46.
#   88.          24.          37.          98.          34.
#   17.          86.          47.         100.          52.
#   95.          99.          26.          55.          19.
#   38.          80.          50.          28.          62.
#   12.          23.          45.          41.          43.
#   56.          87.          15.          73.          92.
#   61.          11.          68.          39.          70.
#   59.           8.           5.           7.          42.
#   53.          96.          75.          66.          74.
#   54.          36.          22.          48.          83.
#   58.          30.          21.           6.          27.
#   13.           9.          60.          10.           4.
#   35.          93.          89.          84.          18.
#   50.64032379]
# Unique date formats in the column: [2364.  684. 2299. ...  159. 1749. 1865.]
# Unique date formats in the column: [0.13       0.24       0.51       0.97       0.36       1.23
#  0.45       0.35       0.12       0.39       1.48       0.87
#  1.11       1.34       1.46       0.23       1.04       0.19
#  0.75       1.33       1.03       1.06       0.76       1.28
#  1.19       0.5        0.14       0.82       1.47       1.39
#  1.21       0.93       0.17       0.29       1.35       1.07
#  0.18       1.27       0.9        0.67       1.32       0.58
#  1.16       0.42       0.27       1.41       0.73       0.98
#  1.49       0.33       0.05       0.08       0.91       0.86
#  0.41       0.07       1.36       1.45       0.68       0.22
#  0.99       0.65       0.34       0.61       0.62       1.31
#  0.94       0.96       0.6        0.69       1.22       1.15
#  1.12       0.37       0.85       0.81       0.49       0.31
#  0.15       0.47       0.38       0.44       0.89       1.3
#  0.66       0.32       0.11       0.7        0.21       0.3
#  1.14       1.25       1.         0.2        0.64       0.88
#  0.78       0.48       1.26       1.37       1.08       0.46
#  0.26       1.02       0.95       0.4        1.05       0.72
#  1.42       1.1        0.28       1.17       0.1        0.55
#  0.84       0.8        0.57       0.16       0.25       1.29
#  1.44       0.06       1.18       0.56       0.74       0.59
#  1.01       0.43       0.09       0.52       0.79       0.71
#  1.43       0.53       0.83       1.13       0.77       1.24
#  1.5        0.92       0.63       1.2        1.4        1.09
#  0.54       1.38       0.77818561]
# Unique date formats in the column: [0.13       0.08       0.09       0.26       0.19       0.2
#  0.07       0.15       0.06       0.3        0.18       0.17
#  0.12       0.05       0.04       0.02       0.16       0.14
#  0.23       0.22       0.28       0.21       0.27       0.1
#  0.11       0.03       0.01       0.25       0.24       0.29
#  0.15581456]
# Unique date formats in the column: [ 92.2  72.6  55.   68.   50.8  45.4  46.2  42.   98.8  52.4  71.6  56.8
#   47.4  76.6  82.8  79.8  20.6  36.4  26.2  59.6  58.4  84.4  75.2  27.
#   41.4  35.   22.6  64.   79.4  47.8  91.   58.   93.2  22.   48.6  37.
#   77.6  88.8  70.8  26.   82.4  32.4  94.2  41.8  56.   70.   37.8  75.6
#   74.4  73.6  44.8  80.2  55.4  52.   26.4  99.   24.6  52.6  44.   75.8
#   23.   39.2  51.4  31.4  73.2  72.   94.8  96.8  77.8  55.6  34.   25.4
#   34.4  80.   78.6  57.4  80.8  35.6  62.6  77.4  49.6  27.2  57.8  86.8
#   87.2  66.6  83.2  75.   85.8  68.8  85.6  72.2  63.8  53.4  88.2  66.4
#   97.8  86.4  63.4  44.6  20.2  66.8  38.8  24.   69.2  23.6  62.8  96.4
#   94.4  43.4  64.6  36.8  63.   54.   50.6  59.8  28.4  31.2  76.8  69.
#   67.8  40.6  49.4  81.6  55.8  71.8  80.4  34.2  53.   31.   97.   98.4
#   86.2  88.6  60.   63.2  37.4  27.6  89.   40.4  81.4  95.2  53.6  90.4
#   33.   64.2  39.8  92.4  35.2  94.   32.2  65.2  72.8  26.8  56.6  38.
#   42.6  42.8  87.4  37.2  68.2  30.   59.   89.2  89.4  73.   30.4  46.8
#   51.8  83.8  58.6  71.4  54.4  80.6  73.4  67.4  22.8  20.8  59.4  62.4
#   98.   59.2  60.8  31.6  90.8  56.2  95.8  82.6  45.8  91.8  30.8  74.
#   93.4  92.8  27.8  70.6  77.2  47.6  38.4  36.6  50.4  52.2  21.   57.2
#   55.2  93.8  91.6  43.6  65.6  98.2  68.6  73.8  96.   50.   28.6  93.6
#   54.2  29.2  71.   81.   23.4  64.8  44.4  97.6  61.   21.6  23.2  43.
#   60.4  76.4  42.4  36.2  70.4  64.4  98.6  24.4  45.2  89.8  87.   90.2
#   47.2  21.4  51.2  41.6  57.   61.2  62.2  22.4  99.2  84.   58.2  96.6
#   54.8  67.   81.2  93.   25.6  41.   69.4  48.8  70.2  25.   32.8  22.2
#   76.2  32.   87.6  20.   45.   40.8  88.   48.2  91.2  84.8  96.2  21.2
#   79.   89.6  35.4  67.6  90.6  40.2  85.2  57.6  47.   87.8  25.2  84.2
#   92.6  54.6  42.2  48.   78.   45.6  51.   71.2  81.8  99.4  69.8  65.
#   91.4  82.2  21.8  37.6  97.4  85.4  20.4  33.8  43.2  33.4  62.   51.6
#   29.6  83.4  83.   39.6  60.2  90.   28.2  58.8  56.4  85.   46.6  75.4
#   99.6  25.8  82.   36.   86.   46.   39.4  88.4  30.6  49.   61.4  34.8
#   53.2  27.4  72.4  76.   78.8  24.2  83.6  61.6  99.8  24.8  79.2  65.4
#   33.6  53.8  30.2  38.2  29.4  61.8  28.8  50.2  40.   39.   67.2  32.6
#   86.6  92.   74.2  35.8  69.6  74.6  63.6  77.   28.   97.2  33.2  84.6
#   44.2  78.2  60.6  31.8  66.2  95.4  29.8  65.8  29.   52.8  49.8  74.8
#   38.6  48.4  46.4  41.2  78.4  26.6  66.   49.2  95.   43.8  34.6  68.4
#   23.8  94.6  79.6  95.6 100. ]

# %% [markdown]
# ## Aggregation And Analysis of the Data

# %%
statistics = data.groupby(['campaign_type','region']).agg({'sales': ['sum', 'mean', 'median'],'units_sold': ['sum', 'mean', 'median'],
'clients_engaged': ['sum', 'mean', 'median'],
'click_rate': ['mean'],
'conversion_rate': ['mean'],
'satisfaction_client (%)': ['mean']
})

statistics.columns = ['Total Sales', 'Average Sales', 'Median Sales','Total Units Sold', 'Average Units Sold', 'Median Units Sold','Total Clients Engaged', 'Average Clients Engaged', 'Median Clients Engaged','Mean Click Rate', 'Mean Conversion Rate', 'Mean Satisfaction Rate']

statistics.reset_index(inplace=True)
print(statistics)
# Out:
#          campaign_type region   Total Sales  Average Sales  Median Sales  \
# 0   Direct Advertising   East  3.583212e+07   76892.971717    77626.7150
# 1   Direct Advertising  North  4.954494e+07   75296.253921    75388.4950
# 2   Direct Advertising  South  3.814813e+07   73645.033460    73563.9050
# 3   Direct Advertising   West  2.885169e+07   72491.671789    72597.0100
# 4                Email   East  2.878335e+07   75152.349991    73281.7000
# 5                Email  North  5.306953e+07   75382.856491    77893.9600
# 6                Email  South  3.695024e+07   78284.397161    81014.2550
# 7                Email   West  2.934986e+07   72290.291951    73273.1700
# 8   Online Advertising   East  6.244167e+07   77088.483210    75792.2100
# 9   Online Advertising  North  1.026149e+08   74737.745976    75617.9122
# 10  Online Advertising  South  7.626984e+07   77510.001212    78550.6700
# 11  Online Advertising   West  6.109327e+07   77333.251177    75072.5900
# 12     Social Networks   East  2.899120e+07   73395.442132    74583.5800
# 13     Social Networks  North  5.455231e+07   74831.694499    76149.1700
# 14     Social Networks  South  3.824943e+07   76960.614728    77670.7500
# 15     Social Networks   West  3.239076e+07   79584.173563    81058.0800
# 16                  TV   East  3.066609e+07   73014.503934    69443.4750
# 17                  TV  North  5.131190e+07   75017.398611    73075.3400
# 18                  TV  South  3.958658e+07   76718.185474    78986.9300
# 19                  TV   West  2.805781e+07   74031.171747    75429.3200
#
#     Total Units Sold  Average Units Sold  Median Units Sold  \
# 0       22280.000000           47.811159          46.000000
# 1       34481.640324           52.403709          53.500000
# 2       25655.000000           49.527027          49.000000
# 3       20153.280648           50.636384          50.000000
# 4       19625.000000           51.240209          53.000000
# 5       35735.000000           50.759943          53.000000
# 6       24248.000000           51.372881          50.000000
# 7       19627.280648           48.343056          48.000000
# 8       41287.000000           50.971605          52.000000
# 9       71081.280648           51.770780          53.000000
# 10      49871.280648           50.682196          50.320162
# 11      40000.000000           50.632911          50.000000
# 12      20186.000000           51.103797          51.000000
# 13      36432.640324           49.976187          51.000000
# 14      25407.640324           51.122013          50.640324
# 15      20270.000000           49.803440          49.000000
# 16      20765.640324           49.442001          50.320162
# 17      34811.280648           50.893685          52.000000
# 18      26025.640324           50.437287          51.000000
# 19      19111.000000           50.424802          51.000000
#
#     Total Clients Engaged  Average Clients Engaged  Median Clients Engaged  \
# 0            6.625390e+05              1421.757477              1426.50000
# 1            9.370040e+05              1424.018237              1428.00000
# 2            8.863010e+05              1711.005792              1855.00000
# 3            6.235640e+05              1566.743719              1634.00000
# 4            5.547070e+05              1448.321149              1432.00000
# 5            9.747900e+05              1384.644886              1348.50000
# 6            8.463310e+05              1793.074153              2033.50000
# 7            6.115970e+05              1506.396513              1399.50000
# 8            1.213332e+06              1497.940741              1472.00000
# 9            1.850574e+06              1347.832461              1313.00000
# 10           1.689232e+06              1716.699155              1904.50000
# 11           1.208160e+06              1529.316436              1498.99224
# 12           5.916140e+05              1497.756962              1564.00000
# 13           9.696510e+05              1330.111111              1276.00000
# 14           8.583290e+05              1727.020058              1917.00000
# 15           6.060640e+05              1489.100699              1480.00000
# 16           5.836250e+05              1389.583333              1352.00000
# 17           8.908909e+05              1302.472131              1264.50000
# 18           8.784020e+05              1702.329457              1774.50000
# 19           5.387920e+05              1421.614776              1330.00000
#
#     Mean Click Rate  Mean Conversion Rate  Mean Satisfaction Rate
# 0          0.760339              0.155021               60.037339
# 1          0.808082              0.160957               59.500608
# 2          0.755012              0.158872               58.522394
# 3          0.770322              0.157653               62.440704
# 4          0.767854              0.156527               61.261619
# 5          0.780426              0.157593               59.932955
# 6          0.812076              0.158072               58.665254
# 7          0.787315              0.157798               57.769951
# 8          0.775951              0.155725               59.189136
# 9          0.769444              0.153478               60.576839
# 10         0.781329              0.157018               61.955691
# 11         0.774430              0.155418               61.511139
# 12         0.776522              0.153989               59.115443
# 13         0.762574              0.155961               59.601646
# 14         0.754383              0.155936               60.634608
# 15         0.778894              0.155065               60.867322
# 16         0.810524              0.153238               61.242857
# 17         0.798857              0.150909               59.958187
# 18         0.776024              0.155891               59.755039
# 19         0.767599              0.152153               58.930343

# %%
#Compaing Type
campaign_statistics = data.groupby('campaign_type').agg({'sales': ['sum', 'mean', 'median'],'units_sold': ['sum', 'mean', 'median'],
'clients_engaged': ['sum', 'mean', 'median'],
'click_rate': ['mean'],
'conversion_rate': ['mean'],
'satisfaction_client (%)': ['mean']
})

campaign_statistics.columns = ['Total Sales', 'Average Sales', 'Median Sales','Total Units Sold', 'Average Units Sold', 'Median Units Sold','Total Clients Engaged', 'Average Clients Engaged', 'Median Clients Engaged','Mean Click Rate', 'Average Conversion Rate', 'Average Customer Satisfaction']
campaign_statistics.reset_index(inplace=True)

print(campaign_statistics)
# Out:
#         campaign_type   Total Sales  Average Sales  Median Sales  \
# 0  Direct Advertising  1.523769e+08   74694.545394     74823.795
# 1               Email  1.481530e+08   75395.916035     76657.880
# 2  Online Advertising  3.024197e+08   76426.511561     76066.460
# 3     Social Networks  1.541837e+08   76027.460105     76807.010
# 4                  TV  1.496224e+08   74848.619359     74561.950
#
#    Total Units Sold  Average Units Sold  Median Units Sold  \
# 0     102569.920971           50.279373          50.320162
# 1      99235.280648           50.501415          51.000000
# 2     202239.561295           51.109315          52.000000
# 3     102296.280648           50.441953          50.640324
# 4     100713.561295           50.381972          51.000000
#
#    Total Clients Engaged  Average Clients Engaged  Median Clients Engaged  \
# 0           3.109408e+06              1524.219600             1580.000000
# 1           2.987425e+06              1520.318058             1522.000000
# 2           5.961298e+06              1506.519566             1498.984479
# 3           3.025658e+06              1491.941792             1509.000000
# 4           2.891710e+06              1446.578258             1416.000000
#
#    Mean Click Rate  Average Conversion Rate  Average Customer Satisfaction
# 0         0.776334                 0.158427                      59.948431
# 1         0.787002                 0.157543                      59.440509
# 2         0.774727                 0.155206                      60.822189
# 3         0.766559                 0.155391                      60.014103
# 4         0.789488                 0.152920                      59.980790

# %%
#Region
region_statistics = data.groupby('region').agg({'sales': ['sum', 'mean', 'median'],'units_sold': ['sum', 'mean', 'median'],
'clients_engaged': ['sum', 'mean', 'median'],
'click_rate': ['mean'],
'conversion_rate': ['mean'],
'satisfaction_client (%)': ['mean']
})

region_statistics.columns = ['Total Sales', 'Average Sales', 'Median Sales','Total Units Sold', 'Average Units Sold', 'Median Units Sold','Total Clients Engaged', 'Average Clients Engaged', 'Median Clients Engaged', 'Mean Click Rate', 'Average Conversion Rate', 'Average Customer Satisfaction']

region_statistics.reset_index(inplace=True)

print(region_statistics)
# Out:
#   region   Total Sales  Average Sales  Median Sales  Total Units Sold  \
# 0   East  1.867144e+08   75470.669992     74569.350     124143.640324
# 1  North  3.110936e+08   74998.456416     75591.920     212541.841943
# 2  South  2.292042e+08   76733.918048     78290.240     151207.561295
# 3   West  1.797434e+08   75522.430700     75158.035     119161.561295
#
#    Average Units Sold  Median Units Sold  Total Clients Engaged  \
# 0           50.179321               51.0           3.605817e+06
# 1           51.239595               52.0           5.622910e+06
# 2           50.621882               50.0           5.158595e+06
# 3           50.067883               50.0           3.588177e+06
#
#    Average Clients Engaged  Median Clients Engaged  Mean Click Rate  \
# 0              1457.484634                  1454.0         0.777717
# 1              1355.571337                  1319.5         0.781080
# 2              1727.015379                  1881.0         0.776224
# 3              1507.637375                  1482.5         0.775617
#
#    Average Conversion Rate  Average Customer Satisfaction
# 0                 0.155017                      60.006629
# 1                 0.155376                      60.023433
# 2                 0.157131                      60.240375
# 3                 0.155617                      60.507311

# %%
avg_conversion_rate = statistics[['campaign_type', 'region', 'Mean Conversion Rate']]
avg_customer_satisfaction = statistics[['campaign_type', 'region', 'Mean Satisfaction Rate']]
print("Average Conversion Rate by Campaign Type and Region:")
print(avg_conversion_rate)
print("\nAverage Customer Satisfaction by Campaign Type and Region:")
print(avg_customer_satisfaction)
# Out:
# Average Conversion Rate by Campaign Type and Region:
#          campaign_type region  Mean Conversion Rate
# 0   Direct Advertising   East              0.155021
# 1   Direct Advertising  North              0.160957
# 2   Direct Advertising  South              0.158872
# 3   Direct Advertising   West              0.157653
# 4                Email   East              0.156527
# 5                Email  North              0.157593
# 6                Email  South              0.158072
# 7                Email   West              0.157798
# 8   Online Advertising   East              0.155725
# 9   Online Advertising  North              0.153478
# 10  Online Advertising  South              0.157018
# 11  Online Advertising   West              0.155418
# 12     Social Networks   East              0.153989
# 13     Social Networks  North              0.155961
# 14     Social Networks  South              0.155936
# 15     Social Networks   West              0.155065
# 16                  TV   East              0.153238
# 17                  TV  North              0.150909
# 18                  TV  South              0.155891
# 19                  TV   West              0.152153
#
# Average Customer Satisfaction by Campaign Type and Region:
#          campaign_type region  Mean Satisfaction Rate
# 0   Direct Advertising   East               60.037339
# 1   Direct Advertising  North               59.500608
# 2   Direct Advertising  South               58.522394
# 3   Direct Advertising   West               62.440704
# 4                Email   East               61.261619
# 5                Email  North               59.932955
# 6                Email  South               58.665254
# 7                Email   West               57.769951
# 8   Online Advertising   East               59.189136
# 9   Online Advertising  North               60.576839
# 10  Online Advertising  South               61.955691
# 11  Online Advertising   West               61.511139
# 12     Social Networks   East               59.115443
# 13     Social Networks  North               59.601646
# 14     Social Networks  South               60.634608
# 15     Social Networks   West               60.867322
# 16                  TV   East               61.242857
# 17                  TV  North               59.958187
# 18                  TV  South               59.755039
# 19                  TV   West               58.930343

# %% [markdown]
# ## Visualization of Data Advanced

# %%
data
# Out:
#            ID        date       campaign_type region customer_age_range  \
# 0      Kq6531  2019-02-19  Online Advertising   East                56+
# 1      Zh5785  2019-04-08  Online Advertising  North                56+
# 2      Si1260  2018-06-28                  TV  South              26-35
# 3      Hl5016  2019-06-10  Online Advertising   West              36-45
# 4      Dj9025  2018-07-14               Email   East              36-45
# ...       ...         ...                 ...    ...                ...
# 11993  Kk3455  2018-07-26                  TV   East              46-55
# 11994  Yd3578  2021-09-27  Direct Advertising   East              36-45
# 11995  Ao1925  2019-06-01  Direct Advertising  South              36-45
# 11996  Vf8403  2020-07-21  Online Advertising   East              46-55
# 11997  Ap3780  2018-08-14  Online Advertising   West              26-35
#
#        gender      sales  units_sold  clients_engaged  click_rate  \
# 0        Male  100735.32        64.0           2364.0        0.13
# 1      Female   15722.29        77.0            684.0        0.24
# 2        Male   35385.73         1.0           2299.0        0.51
# 3        Male  116045.50        44.0           2332.0        0.97
# 4        Male   65039.93        20.0           2564.0        0.36
# ...       ...        ...         ...              ...         ...
# 11993    Male   79508.92        80.0           2203.0        1.29
# 11994  Others  102306.08        52.0           2386.0        0.41
# 11995    Male  117407.35        65.0           2511.0        0.64
# 11996    Male    4728.01        59.0           2736.0        0.08
# 11997  Female   36322.69        76.0           1052.0        0.53
#
#        conversion_rate  satisfaction_client (%)
# 0                 0.13                     92.2
# 1                 0.13                     72.6
# 2                 0.08                     55.0
# 3                 0.09                     68.0
# 4                 0.26                     50.8
# ...                ...                      ...
# 11993             0.27                     55.4
# 11994             0.05                     70.4
# 11995             0.25                     70.0
# 11996             0.08                     30.0
# 11997             0.25                     92.4
#
# [11989 rows x 12 columns]

# %%
# Assuming data is your DataFrame
data['date'] = pd.to_datetime(data['date'], format='%Y-%m-%d')
sns.set(style="whitegrid") 
data['year'] = data['date'].dt.year
plt.figure(figsize=(12, 6)) 
sns.lineplot(data=data, x='year', y='sales', label='sales', color='blue')

# Adding labels and title
plt.xlabel('Date')
plt.ylabel('sales')
plt.title('sales Over Years')
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Assuming data is your DataFrame
df = data.sort_values('date')
sns.set(style="whitegrid") # Setting the style to whitegrid for a clean background
plt.figure(figsize=(12, 6)) # Setting the figure size
sns.lineplot(data=df, x='date', y='sales', label='sales', color='blue')

# Adding labels and title
plt.xlabel('Date')
plt.ylabel('sales')
plt.title('sales Over Time')
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
data.drop(columns='year',axis=1,inplace=True)

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=data, x='sales', hue='campaign_type', kde=True, multiple='stack')
plt.title('Distribution of Sales by Campaign Type')
plt.xlabel('Sales')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='region', y='sales', data=data)
plt.title('Distribution of Sales by Region')
plt.xlabel('Region')
plt.ylabel('Sales')
plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='customer_age_range', y='conversion_rate', data=data)
plt.title('Average Conversion Rate by Customer Age Range')
plt.xlabel('Customer Age Range')
plt.ylabel('Conversion Rate')
plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
plt.figure(figsize=(14, 7))

plt.subplot(1, 2, 1)
sns.barplot(x='region', y='Average Customer Satisfaction', data=region_statistics)
plt.title('Average Customer Satisfaction by Region')
plt.xlabel('Region')
plt.ylabel('Average Customer Satisfaction (%)')

for p in plt.gca().patches:
    plt.gca().annotate('{:.1f}%'.format(p.get_height()), 
                       (p.get_x() + p.get_width() / 2., p.get_height()), 
                       ha='center', va='center', fontsize=10, color='black', xytext=(0, 5), 
                       textcoords='offset points')

plt.subplot(1, 2, 2)
sns.barplot(x='campaign_type', y='Average Customer Satisfaction', data=campaign_statistics)
plt.title('Average Customer Satisfaction by Campaign Type')
plt.xlabel('Campaign Type')
plt.ylabel('Average Customer Satisfaction (%)')

for p in plt.gca().patches:
    plt.gca().annotate('{:.1f}%'.format(p.get_height()), 
                       (p.get_x() + p.get_width() / 2., p.get_height()), 
                       ha='center', va='center', fontsize=10, color='black', xytext=(0, 5), 
                       textcoords='offset points')

plt.tight_layout()

plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
